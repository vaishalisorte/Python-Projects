# %% [markdown]
# Amazon Sales Report

# %%
# import libaries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data
data = pd.read_csv('/content/Universities.csv')
data
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %% [markdown]
# **Data Cleaning**

# %%
data.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
data.shape
# Out:
# (25, 7)

# %%
data.isnull().sum()
# Out:
# Univ        0
# SAT         0
# Top10       0
# Accept      0
# SFRatio     0
# Expenses    0
# GradRate    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
data.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
data.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %%
data.dtypes
# Out:
# Univ        object
# SAT          int64
# Top10        int64
# Accept       int64
# SFRatio      int64
# Expenses     int64
# GradRate     int64
# dtype: object

# %%
x=list(data['Univ'].value_counts()[0:5].keys())
y=data['Univ'].value_counts()[0:5]

# %% [markdown]
# **Data Visulazation**

# %%
plt.figure(figsize=(7,5))

plt.bar(x,y,color=['red','green','pink','purple','blue'])
plt.show()

# %%
plt.hist(data.SAT,color='pink',edgecolor='green')
plt.show()

# %%
data['Univ'].unique()
# Out:
# array(['Brown', 'CalTech', 'CMU', 'Columbia', 'Cornell', 'Dartmouth',
#        'Duke', 'Georgetown', 'Harvard', 'JohnsHopkins', 'MIT',
#        'Northwestern', 'NotreDame', 'PennState', 'Princeton', 'Purdue',
#        'Stanford', 'TexasA&M', 'UCBerkeley', 'UChicago', 'UMichigan',
#        'UPenn', 'UVA', 'UWisconsin', 'Yale'], dtype=object)

# %%
x = list(data['Univ'].value_counts()[0:5].keys())

# %%
plt.figure(figsize=(8,5))
plt.scatter(data.SAT,data.Accept,color='red')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.show()

# %%
sns.lineplot(x='SAT',y='Accept',data=data,color='green')
plt.show()

# %%
x=data['Univ'].value_counts()[0:5]
x
# Out:
# Univ
# Brown         1
# PennState     1
# UWisconsin    1
# UVA           1
# UPenn         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(x,labels=x.index,explode=[0,0,0,0,0.2],autopct='%1.2f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(x,labels=x.index,explode=[0,0,0,0,0.2],autopct='%1.2f%%',shadow=True)
circle=plt.Circle((0,0),color='white',radius=0.50)
plt.gca().add_artist(circle)
plt.show()

# %%
sns.displot(x='Expenses',data=data,color='green',edgecolor='red')
plt.show()

# %%
sns.pairplot(data)
